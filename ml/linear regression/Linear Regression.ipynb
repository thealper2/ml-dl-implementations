# %% [markdown]
# # Gerekli Kütüphaneler

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression as SKLinearRegression
from sklearn import datasets

seed = 42
np.random.seed(seed)

# %% [markdown]
# # Veri Seti

# %%
X, y = datasets.make_regression(
    n_samples=200,
    n_features=1,
    noise=15,
    random_state=seed
)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=seed)

# %% [markdown]
# # Linear Regression

# %%
class LinearRegression:
    def __init__(self, lr=0.01, n_iters=1000):
        # Ogrenme orani (learning rate)
        self.lr = lr
        # Iterasyon sayisi
        self.n_iters = n_iters
        # Agirliklar
        self.W = None
        # Bias
        self.b = None

    def fit(self, X, y):
        n_samples, n_features = X.shape

        # Agirliklar 0 ile doldurulur.
        self.W = np.zeros(n_features)
        # Bias 0 ile baslanir.
        self.b = 0

        # Gradient Descent
        for _ in range(self.n_iters):
            y_pred = np.dot(X, self.W) + self.b

            # Gradyanlar hesaplanir.
            dW = (1 / n_samples) * np.dot(X.T, (y_pred - y))
            db = (1 / n_samples) * np.sum(y_pred - y)

            # Agirlik ve bias guncellenir.
            self.W -= self.lr * dW
            self.b -= self.lr * db

    def predict(self, X):
        y_pred = np.dot(X, self.W) + self.b
        return y_pred

# %% [markdown]
# # Eğitim

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

# %% [markdown]
# # Tahmin

# %%
y_pred = lr.predict(X_test)

# %%
print("R^2 Score:", r2_score(y_test, y_pred))
# Out:
# R^2 Score: 0.9741727576365083

# %%
print("MSE Score:", mean_squared_error(y_test, y_pred))
# Out:
# MSE Score: 159.19223446834505

# %% [markdown]
# # Sonuçlar

# %%
plt.figure(figsize=(3, 4))
plt.plot(X_test, y_test, "rx")
plt.plot(X_test, y_pred, "b")
plt.show()

# %% [markdown]
# # Scikit-Learn

# %%
lr2 = SKLinearRegression()
lr2.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_2 = lr2.predict(X_test)

# %%
print("R^2 Score:", r2_score(y_test, y_pred_2))
# Out:
# R^2 Score: 0.9741633003335014

# %%
print("MSE Score:", mean_squared_error(y_test, y_pred_2))
# Out:
# MSE Score: 159.25052676206116
