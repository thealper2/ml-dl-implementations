# %% [markdown]
# # Gerekli Kütüphaneler

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import Ridge
from sklearn import datasets


seed = 42
np.random.seed(seed)

# %% [markdown]
# # Veri Seti

# %%
X, y = datasets.make_regression(
    n_samples=200,
    n_features=1,
    noise=15,
    random_state=seed
)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=seed)

# %% [markdown]
# # Ridge Regression

# %%
class RidgeRegression:
    def __init__(self, alpha=1.0, lr=0.01, n_iters=1000):
        # Ceza terimi (L2 Regularization)
        self.alpha = alpha
        # Ogrenme orani (learning rate)
        self.lr = lr
        # Iterasyon sayisi
        self.n_iters = n_iters
        # Agirliklar
        self.W = None
        # Bias
        self.b = None

    def fit(self, X, y):
        n_samples, n_features = X.shape

        # Agirliklar 0 ile doldurulur.
        self.W = np.zeros(n_features)
        # Bias 0 ile baslanir.
        self.b = 0

        # Gradient Descent
        for _ in range(self.n_iters):
            y_pred = np.dot(X, self.W) + self.b

            # Gradyanlar hesaplanir.
            dW = (1 / n_samples) * np.dot(X.T, (y_pred - y)) + self.alpha * self.W
            db = (1 / n_samples) * np.sum(y_pred - y)

            # Agirlik ve bias guncellenir.
            self.W -= self.lr * dW
            self.b -= self.lr * db

    def predict(self, X):
        y_pred = np.dot(X, self.W) + self.b
        return y_pred

# %% [markdown]
# # Eğitim

# %%
ridge = RidgeRegression(alpha=0.5)
ridge.fit(X_train, y_train)

# %% [markdown]
# # Tahmin

# %%
y_pred = ridge.predict(X_test)

# %%
print("R^2 Score:", r2_score(y_test, y_pred))
# Out:
# R^2 Score: 0.8283196202312627

# %%
print("MSE Score:", mean_squared_error(y_test, y_pred))
# Out:
# MSE Score: 1058.1920781597742

# %% [markdown]
# # Sonuçlar

# %%
plt.figure(figsize=(3, 4))
plt.plot(X_test, y_test, "rx")
plt.plot(X_test, y_pred, "b")
plt.show()

# %% [markdown]
# # Scikit-Learn

# %%
ridge_scikit = Ridge(alpha=0.5)
ridge_scikit.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.5)

# %%
y_pred_2 = ridge_scikit.predict(X_test)

# %%
print("R^2 Score:", r2_score(y_test, y_pred_2))
# Out:
# R^2 Score: 0.9743128759435608

# %%
print("MSE Score:", mean_squared_error(y_test, y_pred_2))
# Out:
# MSE Score: 158.3285825896175
